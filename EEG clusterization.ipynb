# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 8
#       5 import matplotlib.pyplot as plt
#       6 from pandas.plotting import scatter_matrix
# ----> 8 from sklearn.decomposition import PCA
#       9 from sklearn.preprocessing import StandardScaler
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df = pd.read_csv('data/data_neiro.csv')
df.head()
# Out:
#        AF3      AF4       F3       F4       F7        F8      FC5     FC6  \
# 0 -33.0205 -15.1846 -42.1795   1.6872  42.1793  -1.68720  -5.5436 -3.6154
# 1 -28.6291 -20.0583 -42.5410 -10.4653  35.3100 -15.68600 -19.3110 -2.4344
# 2 -21.8497 -10.9006 -32.0346  -2.3656  39.6993  -0.64483  -4.0523 -1.0830
# 3 -25.1185 -10.9702 -32.7641  -3.4287  32.7378   4.69650  -8.6299 -1.7412
# 4 -19.0316  -9.5886 -29.1108  -3.9459  35.3533   0.79929 -12.6914  1.0144
#
#         O1       O2       P7       P8       T7       T8  Unnamed: 14
# 0  25.7899 -9.88190   5.5436  7.47180  11.8101  17.1128          NaN
# 1  17.4933  3.24420  18.7081  5.09510  17.3683   3.0708          NaN
# 2  26.8081 -3.45840   8.1861  8.40480  15.1209   9.3940          NaN
# 3  16.7637 -9.75860   1.1868  0.91086   4.3315   8.1073          NaN
# 4  13.1068 -0.73692   8.1054 -1.31300   8.1694   8.3442          NaN

# %%
df.columns
# Out:
# Index(['AF3', 'AF4', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'O1', 'O2', 'P7',
#        'P8', 'T7', 'T8', 'Unnamed: 14'],
#       dtype='object')

# %% [markdown]
# ### EDA

# %%
df.shape
# Out:
# (114756, 15)

# %%
df.dtypes
# Out:
# AF3            float64
# AF4            float64
# F3             float64
# F4             float64
# F7             float64
# F8             float64
# FC5            float64
# FC6            float64
# O1             float64
# O2             float64
# P7             float64
# P8             float64
# T7             float64
# T8             float64
# Unnamed: 14    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# AF3    0
# AF4    0
# F3     0
# F4     0
# F7     0
# F8     0
# FC5    0
# FC6    0
# O1     0
# O2     0
# P7     0
# P8     0
# T7     0
# T8     0
# dtype: int64

# %%
df_corr = df.corr()
df_corr
# Out:
#                   AF3       AF4        F3        F4        F7        F8  \
# AF3          1.000000  0.238901  0.295173 -0.022148  0.046043 -0.098836
# AF4          0.238901  1.000000  0.469996  0.536238  0.078092  0.252580
# F3           0.295173  0.469996  1.000000  0.450740  0.129451  0.100206
# F4          -0.022148  0.536238  0.450740  1.000000  0.203050  0.505836
# F7           0.046043  0.078092  0.129451  0.203050  1.000000  0.241373
# F8          -0.098836  0.252580  0.100206  0.505836  0.241373  1.000000
# FC5         -0.058891  0.167437  0.223296  0.609145  0.363434  0.617811
# FC6          0.149241 -0.230325 -0.248514 -0.322661 -0.170475 -0.229566
# O1          -0.136998 -0.053465 -0.161238 -0.145267  0.096632  0.241813
# O2           0.084806 -0.231131 -0.290602 -0.545254 -0.205366 -0.328430
# P7           0.103027 -0.221728 -0.239668 -0.505016 -0.156488 -0.321047
# P8           0.088862 -0.116772 -0.209723 -0.412356 -0.184272 -0.271396
# ...

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.heatmap(df_corr, mask=np.zeros_like(df_corr, dtype=np.bool), cmap = "BrBG",ax=ax)
plt.show()

# %% [markdown]
# - Есть незначащая колонка 'Unnamed: 14'
# - Пропусков в данных нет
# - Все колонки типа float64

# %%
df.drop(columns='Unnamed: 14', inplace=True)
df.head(3)
# Out:
#        AF3      AF4       F3       F4       F7        F8      FC5     FC6  \
# 0 -33.0205 -15.1846 -42.1795   1.6872  42.1793  -1.68720  -5.5436 -3.6154
# 1 -28.6291 -20.0583 -42.5410 -10.4653  35.3100 -15.68600 -19.3110 -2.4344
# 2 -21.8497 -10.9006 -32.0346  -2.3656  39.6993  -0.64483  -4.0523 -1.0830
#
#         O1      O2       P7      P8       T7       T8
# 0  25.7899 -9.8819   5.5436  7.4718  11.8101  17.1128
# 1  17.4933  3.2442  18.7081  5.0951  17.3683   3.0708
# 2  26.8081 -3.4584   8.1861  8.4048  15.1209   9.3940

# %%
df.describe()
# Out:
#                  AF3            AF4             F3             F4  \
# count  114756.000000  114756.000000  114756.000000  114756.000000
# mean        0.012065       0.003977       0.015898      -0.006394
# std         8.960699       9.292756      11.849812      12.009312
# min       -51.624500     -71.382200    -199.866600     -94.795000
# 25%        -5.763050      -5.417950      -6.191325      -7.387200
# 50%        -0.182660      -0.250595      -0.161820      -0.016519
# 75%         5.628700       5.416650       6.334425       7.414350
# max        52.543400      48.431300     208.565200      77.857900
#
#                   F7             F8            FC5            FC6  \
# count  114756.000000  114756.000000  114756.000000  114756.000000
# mean       -0.010433      -0.041711      -0.023973       0.010470
# std        20.638574      13.298301      14.981620      12.938308
# min      -234.664500    -103.468500     -83.861800     -75.213300
# ...
